# %%
''' 
Write a program for a game where the computer generates a
random starting number between 20 and 30.
The player and the computer can remove 1,2 or 3 from the number
in turns. Something like this:

Starting number: 25
How many do you want to remove? 3
22 left
Computer removes 2
20 left
...

The player who has to remove the last value to bring the number
down to 0 is the loser.

1 left
Computer removes 1
You win!

Easy: Get the computer to choose a number between 1â3 at random. 
'''
from random import randint
r=randint(20,30)
print("Starting number:",r)
while(r!=0):
    u=int(input("How many do you want to remove?"))
    r=r-u
    print(r,"left")
    if (r==0):
        print("Computer wins!")
        break
    if (r==1):
        print("Computer removes 1")
        print("You win!")
        break
    elif (r==2):
        print("Computer removes 1")
        r=r-1
    else:
        c=randint(1,3)
        r=r-c
        print("Computer removes ",c)
        print(r,"left")
    if (r==0):print("You win!")
# Out:
# Starting number: 23
# How many do you want to remove?2
# 21 left
# Computer removes  3
# 18 left
# How many do you want to remove?1
# 17 left
# Computer removes  2
# 15 left
# How many do you want to remove?2
# 13 left
# Computer removes  1
# 12 left
# How many do you want to remove?3
# 9 left
# Computer removes  1
# 8 left
# How many do you want to remove?3
# 5 left
# Computer removes  2
# 3 left
# How many do you want to remove?2
# 1 left
# Computer removes 1
# You win!

# %%
''' 
Write a program for a game where the computer generates a
random starting number between 20 and 30.
The player and the computer can remove 1,2 or 3 from the number
in turns. Something like this:

Starting number: 25
How many do you want to remove? 3
22 left
Computer removes 2
20 left
...

The player who has to remove the last value to bring the number
down to 0 is the loser.

1 left
Computer removes 1
You win!

Hard: Get the computer to employ a strategy to try and win. 
'''
from random import randint
r=randint(20,30)
print("Starting number:",r)
u=int(input("How many do you want to remove?"))
r=r-u
print(r,"left")
c=r%4-1
r=r-c
print("Computer removes ",c)
print(r,"left")
while(r!=0):
    u=int(input("How many do you want to remove?"))
    r=r-u
    print(r,"left")
    if (r==0):
        print("Computer wins!")
        break
    if (r==1):
        print("Computer removes 1")
        print("You win!")
        break
    elif (r==2):
        print("Computer removes 1")
        r=r-1
    else:
        c=4-u
        r=r-c
        print("Computer removes ",c)
        print(r,"left")
    if (r==0):print("You win!")
# Out:
# Starting number: 28
# How many do you want to remove?2
# 26 left
# Computer removes  1
# 25 left
# How many do you want to remove?3
# 22 left
# Computer removes  1
# 21 left
# How many do you want to remove?2
# 19 left
# Computer removes  2
# 17 left
# How many do you want to remove?1
# 16 left
# Computer removes  3
# 13 left
# How many do you want to remove?2
# 11 left
# Computer removes  2
# 9 left
# How many do you want to remove?2
# 7 left
# Computer removes  2
# 5 left
# How many do you want to remove?1
# 4 left
# Computer removes  3
# 1 left
# How many do you want to remove?1
# 0 left
# Computer wins!

# %%
'''
Write a program for a Higher / Lower guessing game.
The computer randomly generates a sequence of up to 10 numbers
between 1 and 13. The player after seeing each number in turn
has to decide whether the next number is higher or lower.
If you get 10 guesses right you win the game.

Starting number : 12
Higher(H) or lower(L)? L
Next number 8
Higher(H) or lower(L)? L
Next number 11
You lose

Hints
- Use a condition controlled loop (do until, while etc) to control the
game.
- You do not need to remember all 10 numbers, but  just the current and
the next number.
- Remember to keep a count of the number of guesses. 
'''
from random import randint
f=True
data=[]
for i in range(10):
    data.append(randint(1,13))
i=0
print("Starting number :",data[i])
while (f==True and i<9):
    u=input("Higher(H) or lower(L)? ")
    if (u=="L"):
        if(data[i]<data[i+1]):f=False
    else:
        if(data[i]>data[i+1]):f=False
    print("Next Number",data[i+1])
    i+=1
if(f==False):print("You Lose")
elif (i==9):print("You win")
# Out:
# Starting number : 10
# Higher(H) or lower(L)? L
# Next Number 4
# Higher(H) or lower(L)? L
# Next Number 8
# You Lose

# %%
'''
Extend the above Higher / Lower number guessing game by
- Giving the player two lives
- Allowing only H or L to be entered 
'''
from random import randint
f=0
data=[]
for i in range(10):
    data.append(randint(1,13))
i=0
print("Starting number :",data[i])
while (f<2 and i<9):
    u=input("Higher(H) or lower(L)? ")
    if (u=="L"):
        if(data[i]<data[i+1]):f+=1
        print("Next Number",data[i+1])
        i+=1
    elif (u=="H"):
        if(data[i]>data[i+1]):f+=1
        print("Next Number",data[i+1])
        i+=1
    else:
        print("Invalid data.")
     
if(f==2):print("You Lose")
elif (i==9):print("You win")
# Out:
# Starting number : 10
# Higher(H) or lower(L)? L
# Next Number 13
# Higher(H) or lower(L)? l
# Invalid data.
# Higher(H) or lower(L)? D
# Invalid data.
# Higher(H) or lower(L)? H
# Next Number 3
# You Lose

# %%
'''
Write a program to count the number of words in a sentence.
The user enters a sentence.
The program outputs the number of words in the sentence.
Hint: Look for spaces and full stops in the string. 
'''
s=input("Enter a sentence: ")
w=0
for i in range(len(s)):
    if(s[i]==" " or s[i]=="."):w=w+1
print(w,"words")
# Out:
# Enter a sentence: I am happy today.
# 4 words

# %%
'''
Write a program that will display a sentence backwards after being entered.
Note: You may not use the Python list reverse() function. ;)
'''
s=input("Enter a sentence: ")
w=0
for i in range(len(s)):
    print(s[len(s)-1-i],end='')
# Out:
# Enter a sentence: I am happy today.
# .yadot yppah ma I
